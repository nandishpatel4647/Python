# %% [markdown]
# # Importing Libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Initialization

# %%
class SalesDataAnalyzer:
    def __init__(self):
        self.data = None

    def load_data(self):
        file_path = input(" Enter the CSV file path or name: ")
        try:
            self.data = pd.read_csv(file_path)
            print(" Dataset loaded successfully!")
        except FileNotFoundError:
            print("File not found! Please check the path and try again.")

    def explore_data(self):
        print(" First 5 Rows:")
        print(self.data.head())
        print("\n Info:")
        print(self.data.info())
        print("\nData Types:")
        print(self.data.dtypes)

    def clean_data(self):
        print("\nBefore Cleaning:")
        print(self.data.isnull().sum())
        self.data.fillna(self.data.mean(numeric_only=True), inplace=True)
        print("Missing values filled (numerical columns only).")

    def mathematical_operations(self):
        print("\nSummary Statistics:")
        print(self.data.describe())

    def visualize_data(self):
        print("\nAvailable Columns:")
        print(list(self.data.columns))

        kind = input("\nChoose chart type (Bar / Line / Scatter / Pie / Hist / Area / Heatmap / Boxplot / Violinplot): ").strip().lower()
        x = input("Enter X column ( leave blank for heatmap): ").strip()
        y = input("Enter Y column ( leave blank for pie chart or heatmap): ").strip()

        if kind not in kind:
            print("Invalid chart type.")
            return

        if kind not in["heatmap","pie"] and (x not in self.data.columns or y not in self.data.columns):
            print("Invalid column names. Try Again.")
            return

        try:
            plt.figure(figsize=(6, 5))
            title = f"{kind.title()} Chart - {x} vs {y if y else ''}"

            if kind == "bar":
                self.data.groupby(x)[y].sum().plot(kind="bar")
            elif kind == "line":
                self.data.plot(x=x, y=y, kind="line")
            elif kind == "scatter":
                self.data.plot(x=x, y=y, kind="scatter")
            elif kind == "pie":
                self.data[x].value_counts().plot.pie(autopct='%1.1f%%')
            elif kind == "hist":
                self.data[y].plot(kind="hist")
            elif kind == "area":
                self.data[[x, y]].plot.area(stacked=True)
            elif kind == "heatmap":
                corr = self.data.corr(numeric_only=True)
                sns.heatmap(corr,annot=True, cmap="magma", fmt=".2f")
                title = "Heatmap - Correlation Matrix"
            elif kind == "boxplot":
                sns.boxplot(data=self.data, x=x ,y=y)
            elif kind == "violinplot":
                sns.violinplot(data=self.data, x=x, y=y, hue=" ")            
            else:
                print("Invalid chart type.")
                return
            plt.title(title)
            plt.tight_layout()
            plt.show()
        except Exception as e:
            print(f"Error generating plot: {e}")

    def save_plot(self):
        filename = input("Enter filename to save plot (with .png): ")
        try:
            plt.savefig(filename)
            print(f"Plot saved as {filename}")
        except Exception as e:
            print(f"Could not save plot: {e}")

# %%
analyzer = SalesDataAnalyzer()

while True:
    print("\n === DATA ANALYSIS & VISUALIZATION PROGRAM ===")
    print("1. Load Dataset")
    print("2. Explore Dataset")
    print("3. Handle Missing Data")
    print("4. Generate Summary Statistics")
    print("5. Data Visualization")
    print("6. Save Visualization")
    print("7. Exit")

    choice = input("Enter your choice (1-7): ")

    if choice == "1":
        analyzer.load_data()
    elif choice == "2":
        if analyzer.data is not None:
            analyzer.explore_data()
        else:
            print("Load data first!!!")
    elif choice == "3":
        if analyzer.data is not None:
            analyzer.clean_data()
        else:
            print("Load data first!!!")
    elif choice == "4":
        if analyzer.data is not None:
            analyzer.mathematical_operations()
        else:
            print("Load data first!!!")
    elif choice == "5":
        if analyzer.data is not None:
            analyzer.visualize_data()
        else:
            print("Load data first!!!")
    elif choice == "6":
        if analyzer.data is not None:
            analyzer.save_plot()
        else:
            print("Load data first!!!")
    elif choice == "7":
        print("Exiting...")
        break
    else:
        print("Invalid choice.")
# Out:
#  === DATA ANALYSIS & VISUALIZATION PROGRAM ===
# 1. Load Dataset
# 2. Explore Dataset
# 3. Handle Missing Data
# 4. Generate Summary Statistics
# 5. Data Visualization
# 6. Save Visualization
# 7. Exit
#  Dataset loaded successfully!
#
#  === DATA ANALYSIS & VISUALIZATION PROGRAM ===
# 1. Load Dataset
# 2. Explore Dataset
# 3. Handle Missing Data
# 4. Generate Summary Statistics
# 5. Data Visualization
# 6. Save Visualization
# 7. Exit
# File not found! Please check the path and try again.
#
#  === DATA ANALYSIS & VISUALIZATION PROGRAM ===
# 1. Load Dataset
# 2. Explore Dataset
# 3. Handle Missing Data
# 4. Generate Summary Statistics
# 5. Data Visualization
# 6. Save Visualization
# 7. Exit
#  Dataset loaded successfully!
#
#  === DATA ANALYSIS & VISUALIZATION PROGRAM ===
# 1. Load Dataset
# 2. Explore Dataset
# 3. Handle Missing Data
# 4. Generate Summary Statistics
# 5. Data Visualization
# 6. Save Visualization
# 7. Exit
#
# Available Columns:
# ...

# %%
df = pd.read_csv(r"D:\DS 6 PM\DS AI ML\new_insurance_data.csv")
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
sns.distplot(x=df['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Arnob\AppData\Local\Temp\ipykernel_13824\320612382.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['age'])

# %%
sns.swarmplot(x=df['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#distribution of bmi column
sns.histplot(x=df['bmi'],kde=True)
plt.xlabel('BMI')
plt.ylabel('Count')
plt.show()

# %%
#distribution of children column
plt.subplots(1,3, figsize=(15,5))

plt.subplot(1,3,1)
sns.countplot(x=df['children'])
plt.xlabel('Number of Children')
plt.ylabel('Count')


plt.subplot(1,3,2)
sns.histplot(x=df['children'])
plt.xlabel('Number of Children')
plt.ylabel('Count')


plt.subplot(1,3,3)
sns.distplot(x=df['children'])
plt.xlabel('Number of Children')
plt.ylabel('Count')

plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()
# Out:
# C:\Users\Arnob\AppData\Local\Temp\ipykernel_13824\379711856.py:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['children'])
